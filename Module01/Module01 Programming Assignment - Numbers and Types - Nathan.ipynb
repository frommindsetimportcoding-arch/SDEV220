# %% [markdown]
# # **Nathan Thomas**
# ## Exercise 3.1
# > How many seconds are in an hour? Use the interactive interpreter as a calculator and multiply the number of seconds in a minute (60) by the number of minutes in an hour (also 60).

# %%
seconds_in_minute = 60
minutes_in_hour = 60

seconds_in_hour = seconds_in_minute * minutes_in_hour

print(f'The number of seconds in one hour is {seconds_in_hour}.')
# Out:
# The number of seconds in one hour is 3600.

# %% [markdown]
# ## Exercise 3.2
# > Assign the result from the previous task (seconds in an hour) to a variable called seconds_per_hour.

# %%
seconds_per_hour = seconds_in_hour

print(f'I assigned the variable seconds_per_hour to the same object as seconds_in_hour. The result is still {seconds_per_hour}.')
# Out:
# I assigned the variable seconds_per_hour to the same object as seconds_in_hour. The result is still 3600.

# %% [markdown]
# ## Exercise 3.3
# > How many seconds are in a day? Use your seconds_per_hour variable.

# %%
seconds_per_hour * 24
# Out:
# 86400

# %% [markdown]
# ## Exercise 3.4
# > Calculate seconds per day again, but this time save the result in a variable called *seconds_per_day*.

# %%
hours_per_day = 24
seconds_per_day = seconds_per_hour * hours_per_day

print(f'The number of seconds that pass in one day is {seconds_per_day}.')
# Out:
# The number of seconds that pass in one day is 86400.

# %% [markdown]
# ## Exercise 3.5
# > Divide *seconds_per_day* by *seconds_per_hour*. Use floating-point (/) division.

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %% [markdown]
# ## Exercise 3.6
# > Divide *seconds_per_day* by *seconds_per_hour*, using integer (//) division. Did this number agree with the floating-point value from the previous question, aside from the final .0?

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# ### <mark>Answer to 3.6 question.</mark>
# Yes the numbers agreed aside from the decimal point.
